# %% [markdown]
# <a href="https://colab.research.google.com/github/chingyaousf/Intern-project-2023/blob/main/scripts/MLpredictionDep_05_Model_KNN_MYC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Loading the Dataset
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DeepDEP/filtered_arranged_table.csv")
data
# Out:
#        DepMap_ID  A1BG (1) Exp  A1CF (29974) Exp  A2M (2) Exp  \
# 0     ACH-000001      3.116032          0.056584     0.226509
# 1     ACH-000004      4.178715          0.000000     0.214125
# 2     ACH-000005      4.003602          0.014355     0.137504
# 3     ACH-000007      0.137504          1.405992     0.201634
# 4     ACH-000009      1.464668          3.586164     0.250962
# ...          ...           ...               ...          ...
# 1000  ACH-002785      1.967169          0.000000     2.198494
# 1001  ACH-002800      3.847997          0.000000     5.899901
# 1002  ACH-002834      1.819668          0.014355     0.014355
# 1003  ACH-002847      2.990955          0.000000     7.608440
# 1004  ACH-002926      3.189034          0.000000     9.335390
#
#       A2ML1 (144568) Exp  A3GALT2 (127550) Exp  A4GALT (53947) Exp  \
# 0               0.111031              0.000000            1.035624
# 1               0.344828              0.070389            0.097611
# 2               0.014355              0.000000            0.028569
# 3               0.000000              0.000000            0.014355
# 4               0.000000              0.042644            4.525443
# ...                  ...                   ...                 ...
# 1000            0.000000              0.000000            1.490570
# 1001            0.321928              0.000000            3.206331
# 1002            0.201634              0.000000            2.912650
# 1003            0.014355              0.000000            0.584963
# 1004            0.014355              0.000000            0.000000
#
#       A4GNT (51146) Exp  AAAS (8086) Exp  AACS (65985) Exp  ...  \
# 0              0.176323         5.700440          4.144046  ...
# 1              0.000000         6.336819          3.231125  ...
# 2              0.000000         6.337176          3.781360  ...
# 3              0.000000         5.431289          4.300856  ...
# 4              0.000000         5.674122          4.510962  ...
# ...                 ...              ...               ...  ...
# 1000           0.000000         5.300490          4.314697  ...
# 1001           0.000000         5.831877          3.822730  ...
# 1002           0.028569         5.646451          4.547820  ...
# 1003           0.000000         5.104337          4.228819  ...
# 1004           0.014355         5.204376          4.405992  ...
#
#       ZYG11A (440590) Exp  ZYG11B (79699) Exp  ZYX (7791) Exp  \
# 0                3.282440            2.797013        6.821455
# 1                0.014355            2.032101        7.002252
# 2                0.014355            2.761285        6.826421
# 3                0.014355            1.989139        6.332708
# 4                1.356144            2.956057        7.853185
# ...                   ...                 ...             ...
# 1000             0.014355            4.173127        6.560256
# 1001             0.622930            3.084064        6.596935
# 1002             1.400538            2.568032        6.953498
# 1003             1.480265            2.748461        7.432041
# 1004             0.014355            2.776104        5.182295
#
#       ZZEF1 (23140) Exp  ZZZ3 (26009) Exp  EIF2AK3 (9451) Dep  MYC (4609) Dep  \
# 0              3.010780          4.381975            0.018546        0.807414
# 1              3.444932          4.910733            0.044907        0.999985
# 2              3.524816          5.592457            0.009301        1.000000
# 3              3.673556          3.469886            0.058868        0.999620
# 4              3.442280          3.351911            0.040590        0.979828
# ...                 ...               ...                 ...             ...
# 1000           2.969012          5.276869            0.038095        0.701928
# 1001           3.177918          4.847997            0.177952        0.462993
# 1002           3.087463          4.226509            0.002074        0.911326
# 1003           2.903038          4.660495            0.161273        0.704900
# 1004           2.956057          3.785551            0.017135        0.963046
#
#       NQO1 (1728) Dep  SF3B1 (23451) Dep  SQSTM1 (8878) Dep
# 0            0.076613           1.000000           0.020657
# 1            0.061617           1.000000           0.049385
# 2            0.049535           0.994004           0.015969
# 3            0.036902           0.999886           0.041706
# 4            0.006602           0.973598           0.034535
# ...               ...                ...                ...
# 1000         0.161286           1.000000           0.136197
# 1001         0.054260           1.000000           0.022899
# 1002         0.022301           0.998623           0.013754
# 1003         0.184386           0.999903           0.058351
# 1004         0.022057           0.998453           0.055990
#
# [1005 rows x 17289 columns]

# %%
# Loading the Dataset
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_gt_00.csv")
data
# Out:
#        DepMap_ID  A1CF (29974) Exp  A2ML1 (144568) Exp  AAAS (8086) Exp  \
# 0     ACH-000001          0.056584            0.111031         5.700440
# 1     ACH-000004          0.000000            0.344828         6.336819
# 2     ACH-000005          0.014355            0.014355         6.337176
# 3     ACH-000007          1.405992            0.000000         5.431289
# 4     ACH-000009          3.586164            0.000000         5.674122
# ...          ...               ...                 ...              ...
# 1000  ACH-002785          0.000000            0.000000         5.300490
# 1001  ACH-002800          0.000000            0.321928         5.831877
# 1002  ACH-002834          0.014355            0.201634         5.646451
# 1003  ACH-002847          0.000000            0.014355         5.104337
# 1004  ACH-002926          0.000000            0.014355         5.204376
#
#       AADAC (13) Exp  AADACL2 (344752) Exp  AARS1 (16) Exp  \
# 0           0.790772              0.014355        5.648178
# 1           0.000000              0.000000        8.113221
# 2           0.000000              0.000000        7.435795
# 3           3.547203              0.014355        5.290572
# 4           1.985500              0.000000        7.669523
# ...              ...                   ...             ...
# 1000        0.042644              0.000000        6.572283
# 1001        1.443607              0.000000        7.119460
# 1002        0.000000              0.000000        6.986183
# 1003        0.000000              0.000000        6.690696
# 1004        0.000000              0.000000        6.977623
#
#       AARSD1 (80755) Exp  AATF (26574) Exp  ABCA10 (10349) Exp  ...  \
# 0               4.772414          5.391287            0.137504  ...
# 1               6.458119          6.364572            0.000000  ...
# 2               6.105594          6.668034            0.137504  ...
# 3               5.467606          5.649615            0.422233  ...
# 4               5.499527          6.182295            0.000000  ...
# ...                  ...               ...                 ...  ...
# 1000            5.557655          5.666473            0.189034  ...
# 1001            4.785551          4.644433            0.985500  ...
# 1002            6.202418          5.441616            1.150560  ...
# 1003            5.094236          5.371559            0.150560  ...
# 1004            5.090430          5.877499            0.042644  ...
#
#       ZSCAN10 (84891) Exp  ZSCAN4 (201516) Exp  ZSCAN5A (79149) Exp  \
# 0                0.000000             0.000000             2.653060
# 1                0.137504             0.014355             2.941106
# 2                0.014355             0.042644             3.089159
# 3                0.070389             0.545968             2.675816
# 4                0.137504             0.000000             2.563158
# ...                   ...                  ...                  ...
# 1000             0.000000             0.014355             2.985500
# 1001             0.111031             0.028569             2.523562
# 1002             0.000000             0.000000             2.829850
# 1003             0.000000             1.575312             1.201634
# 1004             0.000000             0.000000             2.675816
#
#       ZSWIM1 (90204) Exp  ZXDC (79364) Exp  EIF2AK3 (9451) Dep  \
# 0               3.276497          4.700994            0.018546
# 1               2.691534          3.619413            0.044907
# 2               2.531069          3.763412            0.009301
# 3               2.518535          3.872829            0.058868
# 4               3.536053          3.773996            0.040590
# ...                  ...               ...                 ...
# 1000            2.182692          2.918386            0.038095
# 1001            2.976364          2.639232            0.177952
# 1002            2.981853          2.904966            0.002074
# 1003            2.121015          2.845992            0.161273
# 1004            2.140779          2.375735            0.017135
#
#       MYC (4609) Dep  NQO1 (1728) Dep  SF3B1 (23451) Dep  SQSTM1 (8878) Dep
# 0           0.807414         0.076613           1.000000           0.020657
# 1           0.999985         0.061617           1.000000           0.049385
# 2           1.000000         0.049535           0.994004           0.015969
# 3           0.999620         0.036902           0.999886           0.041706
# 4           0.979828         0.006602           0.973598           0.034535
# ...              ...              ...                ...                ...
# 1000        0.701928         0.161286           1.000000           0.136197
# 1001        0.462993         0.054260           1.000000           0.022899
# 1002        0.911326         0.022301           0.998623           0.013754
# 1003        0.704900         0.184386           0.999903           0.058351
# 1004        0.963046         0.022057           0.998453           0.055990
#
# [1005 rows x 5715 columns]

# %%
# Loading the Dataset
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_gt_01.csv")
data
# Out:
#        DepMap_ID  ABCA7 (10347) Exp  ABCB11 (8647) Exp  ABHD14B (84836) Exp  \
# 0     ACH-000001           2.121015           0.014355             4.179511
# 1     ACH-000004           4.883132           0.275007             6.203397
# 2     ACH-000005           3.475085           0.189034             5.788686
# 3     ACH-000007           3.898208           0.014355             6.371907
# 4     ACH-000009           3.351911           0.000000             5.212180
# ...          ...                ...                ...                  ...
# 1000  ACH-002785           1.280956           0.000000             4.470537
# 1001  ACH-002800           2.620586           0.014355             4.651339
# 1002  ACH-002834           2.523562           0.000000             4.570463
# 1003  ACH-002847           2.794936           0.000000             5.132577
# 1004  ACH-002926           1.097611           0.014355             5.285032
#
#       ABHD3 (171586) Exp  ABI1 (10006) Exp  ABRA (137735) Exp  ACAA1 (30) Exp  \
# 0               3.021480          3.787641           0.028569        5.439956
# 1               2.682573          4.689299           0.000000        4.457463
# 2               3.754888          5.242603           0.056584        4.144046
# 3               4.418865          4.493775           0.014355        5.983450
# 4               4.241840          5.785289           0.000000        6.383877
# ...                  ...               ...                ...             ...
# 1000            4.308885          5.372256           0.000000        3.909773
# 1001            2.353323          4.463361           0.000000        5.395406
# 1002            3.612352          4.459432           0.000000        5.169123
# 1003            3.428946          4.736064           0.014355        5.360013
# 1004            4.262283          5.133399           0.028569        4.152183
#
#       ACSF3 (197322) Exp  ACSL5 (51703) Exp  ...  ZNF296 (162979) Exp  \
# 0               3.542258           0.226509  ...             0.748461
# 1               4.875289           4.942984  ...             4.012569
# 2               4.606442           5.008989  ...             3.072106
# 3               3.868884           6.969012  ...             2.090853
# 4               4.201634           4.430954  ...             2.094236
# ...                  ...                ...  ...                  ...
# 1000            3.478972           2.277985  ...             0.000000
# 1001            3.229588           1.201634  ...             0.176323
# 1002            3.935460           1.599318  ...             0.422233
# 1003            2.341986           1.769772  ...             0.344828
# 1004            2.946731           5.550285  ...             0.000000
#
#       ZNF341 (84905) Exp  ZNF706 (51123) Exp  ZP3 (7784) Exp  \
# 0               1.895303            6.191405        1.867896
# 1               2.150560            6.282996        2.910733
# 2               2.223423            6.970624        1.859970
# 3               1.655352            5.641835        3.053111
# 4               1.769772            6.298658        1.867896
# ...                  ...                 ...             ...
# 1000            0.765535            6.785551        2.419539
# 1001            1.063503            5.784504        2.933573
# 1002            1.097611            5.563158        3.189034
# 1003            0.887525            7.288912        4.248687
# 1004            1.157044            7.774853        2.996389
#
#       ZPBP2 (124626) Exp  EIF2AK3 (9451) Dep  MYC (4609) Dep  NQO1 (1728) Dep  \
# 0               0.000000            0.018546        0.807414         0.076613
# 1               0.000000            0.044907        0.999985         0.061617
# 2               0.189034            0.009301        1.000000         0.049535
# 3               0.000000            0.058868        0.999620         0.036902
# 4               0.000000            0.040590        0.979828         0.006602
# ...                  ...                 ...             ...              ...
# 1000            0.000000            0.038095        0.701928         0.161286
# 1001            0.028569            0.177952        0.462993         0.054260
# 1002            0.000000            0.002074        0.911326         0.022301
# 1003            0.000000            0.161273        0.704900         0.184386
# 1004            0.000000            0.017135        0.963046         0.022057
#
#       SF3B1 (23451) Dep  SQSTM1 (8878) Dep
# 0              1.000000           0.020657
# 1              1.000000           0.049385
# 2              0.994004           0.015969
# 3              0.999886           0.041706
# 4              0.973598           0.034535
# ...                 ...                ...
# 1000           1.000000           0.136197
# 1001           1.000000           0.022899
# 1002           0.998623           0.013754
# 1003           0.999903           0.058351
# 1004           0.998453           0.055990
#
# [1005 rows x 763 columns]

# %%
# Loading the Dataset
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/MYC_ng_01.csv")
data
# Out:
#        DepMap_ID  A4GNT (51146) Exp  AADAT (51166) Exp  AAGAB (79719) Exp  \
# 0     ACH-000001           0.176323           3.415488           5.752213
# 1     ACH-000004           0.000000           0.042644           4.416164
# 2     ACH-000005           0.000000           0.000000           4.791293
# 3     ACH-000007           0.000000           2.629939           5.053546
# 4     ACH-000009           0.000000           2.684819           5.246028
# ...          ...                ...                ...                ...
# 1000  ACH-002785           0.000000           2.356144           6.511278
# 1001  ACH-002800           0.000000           1.843984           5.974759
# 1002  ACH-002834           0.028569           2.748461           5.193378
# 1003  ACH-002847           0.000000           2.565597           5.491532
# 1004  ACH-002926           0.014355           1.790772           4.001802
#
#       AAK1 (22848) Exp  AAMDC (28971) Exp  AAR2 (25980) Exp  ABCA3 (21) Exp  \
# 0             3.078951           7.923149          5.096768        1.646163
# 1             2.292782           3.884598          5.209843        1.350497
# 2             2.625270           3.663345          5.793896        1.933573
# 3             1.970854           3.915521          3.957915        0.400538
# 4             3.397803           7.032211          5.878480        3.419539
# ...                ...                ...               ...             ...
# 1000          3.819668           5.254367          4.983222        2.017922
# 1001          4.034744           6.596041          5.234578        2.459432
# 1002          4.133399           5.602588          4.958379        0.042644
# 1003          3.396434           9.623186          4.072106        0.526069
# 1004          3.033863           4.946263          4.440952        0.111031
#
#       ABCB6 (10058) Exp  ABCC9 (10060) Exp  ...  ZSWIM8 (23053) Exp  \
# 0              4.811985           0.014355  ...            5.663345
# 1              4.973152           0.422233  ...            4.969012
# 2              5.231509           0.765535  ...            4.448901
# 3              3.392317           0.014355  ...            4.743623
# 4              5.590662           5.248307  ...            5.383013
# ...                 ...                ...  ...                 ...
# 1000           3.730096           0.028569  ...            4.686501
# 1001           2.805292           3.829850  ...            5.363522
# 1002           3.226509           0.765535  ...            5.765800
# 1003           3.379898           1.589763  ...            6.049413
# 1004           4.672991           0.014355  ...            5.053546
#
#       ZXDB (158586) Exp  ZYG11B (79699) Exp  ZYX (7791) Exp  ZZZ3 (26009) Exp  \
# 0              1.914565            2.797013        6.821455          4.381975
# 1              1.622930            2.032101        7.002252          4.910733
# 2              1.773996            2.761285        6.826421          5.592457
# 3              1.761285            1.989139        6.332708          3.469886
# 4              2.176323            2.956057        7.853185          3.351911
# ...                 ...                 ...             ...               ...
# 1000           2.817623            4.173127        6.560256          5.276869
# 1001           2.634593            3.084064        6.596935          4.847997
# 1002           3.224966            2.568032        6.953498          4.226509
# 1003           1.867896            2.748461        7.432041          4.660495
# 1004           1.879706            2.776104        5.182295          3.785551
#
#       EIF2AK3 (9451) Dep  MYC (4609) Dep  NQO1 (1728) Dep  SF3B1 (23451) Dep  \
# 0               0.018546        0.807414         0.076613           1.000000
# 1               0.044907        0.999985         0.061617           1.000000
# 2               0.009301        1.000000         0.049535           0.994004
# 3               0.058868        0.999620         0.036902           0.999886
# 4               0.040590        0.979828         0.006602           0.973598
# ...                  ...             ...              ...                ...
# 1000            0.038095        0.701928         0.161286           1.000000
# 1001            0.177952        0.462993         0.054260           1.000000
# 1002            0.002074        0.911326         0.022301           0.998623
# 1003            0.161273        0.704900         0.184386           0.999903
# 1004            0.017135        0.963046         0.022057           0.998453
#
#       SQSTM1 (8878) Dep
# 0              0.020657
# 1              0.049385
# 2              0.015969
# 3              0.041706
# 4              0.034535
# ...                 ...
# 1000           0.136197
# 1001           0.022899
# 1002           0.013754
# 1003           0.058351
# 1004           0.055990
#
# [1005 rows x 3979 columns]

# %%
from numpy import true_divide
# Cleaning Column Names
clean_column_names = {}
for column in data.columns:
    clean_column_names[column] = column.strip().replace(' ', '_').replace('(', '').replace(')', '')

data.rename(columns=clean_column_names, inplace=True)
data
# Out:
#        DepMap_ID  A4GNT_51146_Exp  AADAT_51166_Exp  AAGAB_79719_Exp  \
# 0     ACH-000001         0.176323         3.415488         5.752213
# 1     ACH-000004         0.000000         0.042644         4.416164
# 2     ACH-000005         0.000000         0.000000         4.791293
# 3     ACH-000007         0.000000         2.629939         5.053546
# 4     ACH-000009         0.000000         2.684819         5.246028
# ...          ...              ...              ...              ...
# 1000  ACH-002785         0.000000         2.356144         6.511278
# 1001  ACH-002800         0.000000         1.843984         5.974759
# 1002  ACH-002834         0.028569         2.748461         5.193378
# 1003  ACH-002847         0.000000         2.565597         5.491532
# 1004  ACH-002926         0.014355         1.790772         4.001802
#
#       AAK1_22848_Exp  AAMDC_28971_Exp  AAR2_25980_Exp  ABCA3_21_Exp  \
# 0           3.078951         7.923149        5.096768      1.646163
# 1           2.292782         3.884598        5.209843      1.350497
# 2           2.625270         3.663345        5.793896      1.933573
# 3           1.970854         3.915521        3.957915      0.400538
# 4           3.397803         7.032211        5.878480      3.419539
# ...              ...              ...             ...           ...
# 1000        3.819668         5.254367        4.983222      2.017922
# 1001        4.034744         6.596041        5.234578      2.459432
# 1002        4.133399         5.602588        4.958379      0.042644
# 1003        3.396434         9.623186        4.072106      0.526069
# 1004        3.033863         4.946263        4.440952      0.111031
#
#       ABCB6_10058_Exp  ABCC9_10060_Exp  ...  ZSWIM8_23053_Exp  \
# 0            4.811985         0.014355  ...          5.663345
# 1            4.973152         0.422233  ...          4.969012
# 2            5.231509         0.765535  ...          4.448901
# 3            3.392317         0.014355  ...          4.743623
# 4            5.590662         5.248307  ...          5.383013
# ...               ...              ...  ...               ...
# 1000         3.730096         0.028569  ...          4.686501
# 1001         2.805292         3.829850  ...          5.363522
# 1002         3.226509         0.765535  ...          5.765800
# 1003         3.379898         1.589763  ...          6.049413
# 1004         4.672991         0.014355  ...          5.053546
#
#       ZXDB_158586_Exp  ZYG11B_79699_Exp  ZYX_7791_Exp  ZZZ3_26009_Exp  \
# 0            1.914565          2.797013      6.821455        4.381975
# 1            1.622930          2.032101      7.002252        4.910733
# 2            1.773996          2.761285      6.826421        5.592457
# 3            1.761285          1.989139      6.332708        3.469886
# 4            2.176323          2.956057      7.853185        3.351911
# ...               ...               ...           ...             ...
# 1000         2.817623          4.173127      6.560256        5.276869
# 1001         2.634593          3.084064      6.596935        4.847997
# 1002         3.224966          2.568032      6.953498        4.226509
# 1003         1.867896          2.748461      7.432041        4.660495
# 1004         1.879706          2.776104      5.182295        3.785551
#
#       EIF2AK3_9451_Dep  MYC_4609_Dep  NQO1_1728_Dep  SF3B1_23451_Dep  \
# 0             0.018546      0.807414       0.076613         1.000000
# 1             0.044907      0.999985       0.061617         1.000000
# 2             0.009301      1.000000       0.049535         0.994004
# 3             0.058868      0.999620       0.036902         0.999886
# 4             0.040590      0.979828       0.006602         0.973598
# ...                ...           ...            ...              ...
# 1000          0.038095      0.701928       0.161286         1.000000
# 1001          0.177952      0.462993       0.054260         1.000000
# 1002          0.002074      0.911326       0.022301         0.998623
# 1003          0.161273      0.704900       0.184386         0.999903
# 1004          0.017135      0.963046       0.022057         0.998453
#
#       SQSTM1_8878_Dep
# 0            0.020657
# 1            0.049385
# 2            0.015969
# 3            0.041706
# 4            0.034535
# ...               ...
# 1000         0.136197
# 1001         0.022899
# 1002         0.013754
# 1003         0.058351
# 1004         0.055990
#
# [1005 rows x 3979 columns]

# %%
# Exclude 'DepMap_ID' column
data_without_id = data.drop(columns=['DepMap_ID'])

# Extracting Features and Targets
features = data_without_id.drop(columns=[col for col in data_without_id.columns if 'Dep' in col])
# targets = data_without_id[[col for col in data_without_id.columns if 'Dep' in col]]
targets = data_without_id[["MYC_4609_Dep"]]

targets
# Out:
#       MYC_4609_Dep
# 0         0.807414
# 1         0.999985
# 2         1.000000
# 3         0.999620
# 4         0.979828
# ...            ...
# 1000      0.701928
# 1001      0.462993
# 1002      0.911326
# 1003      0.704900
# 1004      0.963046
#
# [1005 rows x 1 columns]

# %%
# Splitting the Data into Train and Test Sets
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# %%
# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create and train the KNN regressor
knn = KNeighborsRegressor(n_neighbors=40)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=40)

# %%
# Make predictions
y_pred = knn.predict(X_test_scaled)

# %%
# Printing Predicted Values
print('Predicted Values:', y_pred)
# Out:
# Predicted Values: [[0.95728845]
#  [0.98347472]
#  [0.92788996]
#  [0.96679363]
#  [0.9387841 ]
#  [0.97153143]
#  [0.96918133]
#  [0.94868945]
#  [0.99069758]
#  [0.9488658 ]
#  [0.93691454]
#  [0.99303799]
#  [0.95570286]
#  [0.98380647]
#  [0.98750109]
#  [0.98104851]
#  [0.97685743]
#  [0.95218138]
#  [0.99217972]
#  [0.98240585]
#  [0.99234519]
#  [0.99366512]
#  [0.95925042]
#  [0.96990676]
#  [0.97224724]
#  [0.98930924]
#  [0.99361344]
#  [0.99194742]
#  [0.9926361 ]
#  [0.99086851]
#  [0.93141277]
#  [0.96892941]
#  [0.97857685]
#  [0.98084826]
#  [0.94944243]
#  [0.92656149]
#  [0.98368636]
#  [0.58927287]
#  [0.99150468]
#  [0.97123709]
#  [0.98699936]
#  [0.93337768]
#  [0.99004537]
#  [0.98072769]
#  [0.90545372]
#  [0.9950149 ]
#  [0.96529487]
#  [0.99171931]
#  [0.99165089]
#  [0.93268811]
#  [0.98869698]
#  [0.99143887]
#  [0.98758358]
#  [0.9921775 ]
#  [0.95112204]
#  [0.98572452]
#  [0.98866328]
#  [0.98749521]
#  [0.96153427]
#  [0.98430908]
#  [0.97924655]
#  [0.97232554]
#  [0.98952233]
#  [0.77727241]
#  [0.98276585]
#  [0.98138971]
#  [0.63752053]
#  [0.99190494]
#  [0.99516927]
#  [0.99256465]
#  [0.92279551]
#  [0.98864378]
#  [0.95900171]
#  [0.97711926]
#  [0.98861034]
#  [0.95942544]
#  [0.95047653]
#  [0.98895773]
#  [0.99448075]
#  [0.94647113]
#  [0.94288526]
#  [0.96760017]
#  [0.98257772]
#  [0.94879193]
#  [0.9420608 ]
#  [0.93376115]
#  [0.97239965]
#  [0.95102027]
#  [0.99336634]
#  [0.94949381]
#  [0.96637742]
#  [0.95227907]
#  [0.93113064]
#  [0.98614727]
#  [0.96431587]
#  [0.96834192]
#  [0.95379266]
#  [0.97628288]
#  [0.99462317]
#  [0.94383511]
#  [0.94188478]
#  [0.94246908]
#  [0.94499099]
#  [0.96913081]
#  [0.99119496]
#  [0.98814002]
#  [0.99269885]
#  [0.98810692]
#  [0.98423666]
#  [0.993291  ]
#  [0.98682163]
#  [0.95801823]
#  [0.95747251]
#  [0.93021073]
#  [0.99395359]
#  [0.99009322]
#  [0.99057275]
#  [0.9608856 ]
#  [0.99187823]
#  [0.99037447]
#  [0.99183305]
#  [0.98553227]
#  [0.99417833]
#  [0.92804578]
#  [0.9529659 ]
#  [0.98889413]
#  [0.99205134]
#  [0.96680828]
#  [0.98872816]
#  [0.99230987]
#  [0.99118162]
#  [0.94559601]
#  [0.92978208]
#  [0.94025151]
#  [0.93767022]
#  [0.99515717]
#  [0.96299583]
#  [0.99009796]
#  [0.98952714]
#  [0.96596734]
#  [0.98729032]
#  [0.95090238]
#  [0.9637958 ]
#  [0.96354861]
#  [0.95032546]
#  [0.99325622]
#  [0.99123986]
#  [0.98859672]
#  [0.99184046]
#  [0.9399174 ]
#  [0.95459486]
#  [0.98573545]
#  [0.93562439]
#  [0.99085735]
#  [0.96868322]
#  [0.96152603]
#  [0.92678542]
#  [0.95169278]
#  [0.9411606 ]
#  [0.98541853]
#  [0.98897075]
#  [0.99132798]
#  [0.96127771]
#  [0.99165573]
#  [0.92814028]
#  [0.9849571 ]
#  [0.96661208]
#  [0.98889771]
#  [0.99068199]
#  [0.95935072]
#  [0.97474028]
#  [0.97684562]
#  [0.99174912]
#  [0.99033748]
#  [0.94988167]
#  [0.99204862]
#  [0.98176847]
#  [0.9920653 ]
#  [0.96859851]
#  [0.96092878]
#  [0.92832988]
#  [0.95134126]
#  [0.95104126]
#  [0.98877333]
#  [0.9819257 ]
#  [0.98513537]
#  [0.63865474]
#  [0.91672876]
#  [0.95152331]
#  [0.98755979]
#  [0.99171305]
#  [0.98717939]
#  [0.99019607]
#  [0.9928934 ]
#  [0.98696038]
#  [0.95099714]
#  [0.97734718]
#  [0.99144498]
#  [0.96465915]
#  [0.9756174 ]
#  [0.99056719]]

# %%
# Evaluating the Model
# Mean Squared Error. It is a common metric used to measure the average squared difference between the predicted and actual values in regression tasks.
# Lower values of MSE indicate better model performance, as it means the predicted values are closer to the actual values. However, MSE is sensitive to outliers since the squared differences magnify their impact on the overall error.

mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 0.019926625211772412

# %%
# Mean Absolute Error (MAE) measures the average absolute difference between the predicted and actual values. It gives a straightforward measure of the average prediction error. Lower MAE values indicate better accuracy.

from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)
# Out:
# Mean Absolute Error: 0.0559998707856077

# %%
# Calculate R-squared (coefficient of determination)

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print('Coefficient of Determination (R-squared):', r2)
# Out:
# Coefficient of Determination (R-squared): 0.09126300267672072

# %%
# MYC_filtered_arranged_table.csv

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)

r2 = r2_score(y_test, y_pred)
print('Coefficient of Determination (R-squared):', r2)
# Out:
# Mean Squared Error: 0.01940766099217977
# Mean Absolute Error: 0.05902278322608873
# Coefficient of Determination (R-squared): 0.11492992979653349

# %%
# MYC_gt_00.csv

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)

r2 = r2_score(y_test, y_pred)
print('Coefficient of Determination (R-squared):', r2)
# Out:
# Mean Squared Error: 0.017765045101623734
# Mean Absolute Error: 0.06168802987361822
# Coefficient of Determination (R-squared): 0.18984004710317715

# %%
# MYC_gt_01.csv

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)

r2 = r2_score(y_test, y_pred)
print('Coefficient of Determination (R-squared):', r2)
# Out:
# Mean Squared Error: 0.017290535536361465
# Mean Absolute Error: 0.06304910046138316
# Coefficient of Determination (R-squared): 0.21147965706998972

# %%
# MYC_ng_01.csv

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)

r2 = r2_score(y_test, y_pred)
print('Coefficient of Determination (R-squared):', r2)
# Out:
# Mean Squared Error: 0.019926625211772412
# Mean Absolute Error: 0.0559998707856077
# Coefficient of Determination (R-squared): 0.09126300267672072

# %%
# MYC_filtered_arranged_table.csv

# Retrieve the 'DepMap_ID' column before splitting
depmap_id_column = data['DepMap_ID']

# Create a new DataFrame for the test set with the predicted and actual values
test_data = X_test.copy()

# Add 'DepMap_ID' column to test_data
test_data.insert(0, 'DepMap_ID', depmap_id_column.iloc[X_test.index].values)

target_col = "MYC_4609_Dep"  # Replace with the name of your target column

pred_col = f'Pred_{target_col}'
test_data[pred_col] = y_pred[:, 0]  # Assign predicted values to the new column

actual_col = target_col
test_data[actual_col] = y_test.values  # Assign actual values to the target column

# Save the DataFrame to a CSV file
test_data.to_csv("/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_filtered_arranged_table.csv", index=False)

# Display the updated DataFrame
test_data
# Out:
#       DepMap_ID  A1BG_1_Exp  A1CF_29974_Exp  A2M_2_Exp  A2ML1_144568_Exp  \
# 926  ACH-001858    0.176323        0.056584   0.097611          0.014355
# 630  ACH-000962    4.410748        0.028569   0.056584          0.000000
# 682  ACH-001164    4.262283        0.000000   5.371210          0.000000
# 514  ACH-000799    4.440288        0.014355   6.867773          0.014355
# 365  ACH-000571    5.489928        0.000000   0.678072          0.000000
# ..          ...         ...             ...        ...               ...
# 208  ACH-000339    0.111031        0.014355   0.028569          0.000000
# 778  ACH-001454    0.400538        0.000000   0.189034          0.163499
# 334  ACH-000522    4.157044        0.000000   0.214125          0.000000
# 210  ACH-000343    4.189034        0.042644   0.014355          0.367371
# 350  ACH-000549    0.056584        0.000000   0.400538          0.111031
#
#      A3GALT2_127550_Exp  A4GALT_53947_Exp  A4GNT_51146_Exp  AAAS_8086_Exp  \
# 926            0.000000          3.035624         0.056584       5.299758
# 630            0.028569          1.189034         0.014355       5.620000
# 682            0.000000          1.765535         0.000000       5.003152
# 514            0.163499          0.641546         0.124328       5.484460
# 365            0.042644          3.016140         0.214125       5.319040
# ..                  ...               ...              ...            ...
# 208            0.000000          1.378512         0.028569       5.497612
# 778            0.000000          4.678072         0.000000       4.751678
# 334            0.000000          2.893362         0.014355       6.321026
# 210            0.000000          2.304511         0.097611       5.744699
# 350            0.028569          5.224581         0.000000       5.139142
#
#      AACS_65985_Exp  ...  ZXDA_7789_Exp  ZXDB_158586_Exp  ZXDC_79364_Exp  \
# 926        4.263034  ...       0.992768         2.451541        2.889474
# 630        4.238023  ...       1.599318         2.538538        3.364572
# 682        3.489286  ...       0.495695         1.244887        2.711495
# 514        4.268285  ...       0.807355         1.475085        4.251719
# 365        4.609400  ...       0.516015         1.918386        3.526069
# ..              ...  ...            ...              ...             ...
# 208        3.605257  ...       0.505891         1.769772        3.135863
# 778        4.521051  ...       1.104337         1.847997        2.754888
# 334        3.298658  ...       0.823749         1.879706        3.442280
# 210        4.082362  ...       5.763943         5.212180        3.607626
# 350        3.994580  ...       1.448901         1.974529        4.050502
#
#      ZYG11A_440590_Exp  ZYG11B_79699_Exp  ZYX_7791_Exp  ZZEF1_23140_Exp  \
# 926           0.815575          2.976364      7.199967         3.465974
# 630           2.307429          2.980025      6.212569         3.214125
# 682           0.333424          2.495695      4.735522         2.107688
# 514           0.475085          2.077243      7.966477         4.179511
# 365           0.000000          3.114367      6.934281         4.079805
# ..                 ...               ...           ...              ...
# 208           2.319040          2.367371      7.258236         2.841973
# 778           1.220330          2.459432      5.038261         2.782409
# 334           2.761285          3.238787      7.097295         4.590362
# 210           3.411426          3.869871      3.674687         2.611172
# 350           0.464668          2.176323      5.941811         3.204767
#
#      ZZZ3_26009_Exp  Pred_MYC_4609_Dep  MYC_4609_Dep
# 926        4.780310           0.935787      0.986031
# 630        3.919340           0.968603      0.808635
# 682        3.363171           0.940972      0.999965
# 514        3.481557           0.955771      0.973706
# 365        4.527946           0.946630      0.947456
# ..              ...                ...           ...
# 208        4.584361           0.967792      0.981174
# 778        2.657640           0.991358      0.851388
# 334        4.649041           0.964909      0.999722
# 210        4.669027           0.981832      0.971561
# 350        3.982765           0.990607      0.999956
#
# [201 rows x 17286 columns]

# %%
# MYC_gt_00.csv

# Retrieve the 'DepMap_ID' column before splitting
depmap_id_column = data['DepMap_ID']

# Create a new DataFrame for the test set with the predicted and actual values
test_data = X_test.copy()

# Add 'DepMap_ID' column to test_data
test_data.insert(0, 'DepMap_ID', depmap_id_column.iloc[X_test.index].values)

target_col = "MYC_4609_Dep"  # Replace with the name of your target column

pred_col = f'Pred_{target_col}'
test_data[pred_col] = y_pred[:, 0]  # Assign predicted values to the new column

actual_col = target_col
test_data[actual_col] = y_test.values  # Assign actual values to the target column

# Save the DataFrame to a CSV file
test_data.to_csv("/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_gt_00.csv", index=False)

# Display the updated DataFrame
test_data
# Out:
#       DepMap_ID  A1CF_29974_Exp  A2ML1_144568_Exp  AAAS_8086_Exp  \
# 926  ACH-001858        0.056584          0.014355       5.299758
# 630  ACH-000962        0.028569          0.000000       5.620000
# 682  ACH-001164        0.000000          0.000000       5.003152
# 514  ACH-000799        0.014355          0.014355       5.484460
# 365  ACH-000571        0.000000          0.000000       5.319040
# ..          ...             ...               ...            ...
# 208  ACH-000339        0.014355          0.000000       5.497612
# 778  ACH-001454        0.000000          0.163499       4.751678
# 334  ACH-000522        0.000000          0.000000       6.321026
# 210  ACH-000343        0.042644          0.367371       5.744699
# 350  ACH-000549        0.000000          0.111031       5.139142
#
#      AADAC_13_Exp  AADACL2_344752_Exp  AARS1_16_Exp  AARSD1_80755_Exp  \
# 926      1.700440                 0.0      6.384913          5.039577
# 630      0.000000                 0.0      6.764872          5.369815
# 682      0.000000                 0.0      4.882643          5.192194
# 514      0.000000                 0.0      6.563616          5.329124
# 365      0.056584                 0.0      6.850874          5.717813
# ..            ...                 ...           ...               ...
# 208      0.367371                 0.0      5.939932          5.288359
# 778      0.097611                 0.0      5.241077          5.548437
# 334      0.111031                 0.0      6.887282          5.351911
# 210      0.000000                 0.0      6.798051          6.445429
# 350      1.269033                 0.0      6.884354          5.206331
#
#      AATF_26574_Exp  ABCA10_10349_Exp  ...  ZP3_7784_Exp  ZPBP_11055_Exp  \
# 926        5.975217          0.070389  ...      3.648465        0.000000
# 630        5.901832          0.454176  ...      5.135863        0.070389
# 682        4.475085          0.111031  ...      3.442280        0.000000
# 514        6.136684          0.773996  ...      3.881665        0.000000
# 365        6.174526          0.014355  ...      0.137504        0.000000
# ..              ...               ...  ...           ...             ...
# 208        6.398658          0.084064  ...      0.669027        0.000000
# 778        5.569552          0.137504  ...      4.793376        0.000000
# 334        6.156032          0.163499  ...      4.120186        0.000000
# 210        6.333245          0.000000  ...      5.312520        0.000000
# 350        5.377471          1.646163  ...      4.272023        0.000000
#
#      ZPBP2_124626_Exp  ZSCAN10_84891_Exp  ZSCAN4_201516_Exp  \
# 926               0.0           0.000000           0.014355
# 630               0.0           0.014355           0.000000
# 682               0.0           0.176323           0.263034
# 514               0.0           0.014355           0.516015
# 365               0.0           0.000000           0.000000
# ..                ...                ...                ...
# 208               0.0           0.000000           0.028569
# 778               0.0           0.000000           0.124328
# 334               0.0           0.000000           0.000000
# 210               0.0           0.137504           0.014355
# 350               0.0           0.070389           1.831877
#
#      ZSCAN5A_79149_Exp  ZSWIM1_90204_Exp  ZXDC_79364_Exp  Pred_MYC_4609_Dep  \
# 926           2.632268          2.594549        2.889474           0.936619
# 630           2.731183          2.998196        3.364572           0.962573
# 682           2.922198          2.117695        2.711495           0.917992
# 514           2.361768          2.987321        4.251719           0.941115
# 365           2.803227          3.435629        3.526069           0.949198
# ..                 ...               ...             ...                ...
# 208           2.100978          3.436961        3.135863           0.955332
# 778           2.073820          2.298658        2.754888           0.990751
# 334           3.549669          3.240314        3.442280           0.963468
# 210           2.799087          2.989139        3.607626           0.980202
# 350           3.063503          3.368768        4.050502           0.992948
#
#      MYC_4609_Dep
# 926      0.986031
# 630      0.808635
# 682      0.999965
# 514      0.973706
# 365      0.947456
# ..            ...
# 208      0.981174
# 778      0.851388
# 334      0.999722
# 210      0.971561
# 350      0.999956
#
# [201 rows x 5712 columns]

# %%
# MYC_gt_01.csv

# Retrieve the 'DepMap_ID' column before splitting
depmap_id_column = data['DepMap_ID']

# Create a new DataFrame for the test set with the predicted and actual values
test_data = X_test.copy()

# Add 'DepMap_ID' column to test_data
test_data.insert(0, 'DepMap_ID', depmap_id_column.iloc[X_test.index].values)

target_col = "MYC_4609_Dep"  # Replace with the name of your target column

pred_col = f'Pred_{target_col}'
test_data[pred_col] = y_pred[:, 0]  # Assign predicted values to the new column

actual_col = target_col
test_data[actual_col] = y_test.values  # Assign actual values to the target column

# Save the DataFrame to a CSV file
test_data.to_csv("/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_gt_01.csv", index=False)

# Display the updated DataFrame
test_data
# Out:
#       DepMap_ID  ABCA7_10347_Exp  ABCB11_8647_Exp  ABHD14B_84836_Exp  \
# 926  ACH-001858         2.046142         0.014355           4.527321
# 630  ACH-000962         4.886550         0.000000           5.649328
# 682  ACH-001164         0.485427         0.000000           4.736605
# 514  ACH-000799         2.553361         0.014355           4.314697
# 365  ACH-000571         3.524816         0.000000           5.910972
# ..          ...              ...              ...                ...
# 208  ACH-000339         2.889474         0.014355           4.148121
# 778  ACH-001454         3.962549         0.150560           4.738227
# 334  ACH-000522         0.839960         0.000000           4.509062
# 210  ACH-000343         4.416164         0.000000           6.098243
# 350  ACH-000549         4.586765         0.575312           4.807355
#
#      ABHD3_171586_Exp  ABI1_10006_Exp  ABRA_137735_Exp  ACAA1_30_Exp  \
# 926          4.144862        5.149747         0.000000      5.024586
# 630          3.912650        4.201634         0.000000      4.430285
# 682          3.221877        3.922198         0.014355      4.969012
# 514          3.472488        3.553361         0.000000      5.271276
# 365          3.806324        3.922198         0.000000      5.756756
# ..                ...             ...              ...           ...
# 208          3.645010        4.455492         0.014355      4.890447
# 778          4.681449        3.865919         0.042644      5.942984
# 334          3.060047        4.657640         0.000000      5.003152
# 210          4.347666        3.269033         0.084064      4.725196
# 350          3.638074        4.257765         0.014355      5.533563
#
#      ACSF3_197322_Exp  ACSL5_51703_Exp  ...  ZFP36L2_678_Exp  \
# 926          2.260026         4.154616  ...         3.595742
# 630          3.581351         0.111031  ...         2.879706
# 682          3.063503         1.063503  ...         3.519793
# 514          3.946731         0.189034  ...         5.818646
# 365          4.410070         3.214125  ...         3.426265
# ..                ...              ...  ...              ...
# 208          3.161888         2.974529  ...         3.547203
# 778          3.560715         6.286142  ...         4.473137
# 334          3.189034         0.495695  ...         3.905928
# 210          2.959770         0.111031  ...         4.229588
# 350          3.451541         4.611763  ...         5.140779
#
#      ZG16B_124220_Exp  ZNF276_92822_Exp  ZNF296_162979_Exp  ZNF341_84905_Exp  \
# 926          1.250962          2.648465           0.704872          1.411426
# 630          0.400538          3.808385           1.292782          2.130931
# 682          2.073820          4.084915           0.970854          1.207893
# 514          1.195348          4.792855           0.176323          1.575312
# 365          0.669027          3.943921           0.214125          1.906891
# ..                ...               ...                ...               ...
# 208          2.513491          3.523562           1.659925          1.361768
# 778          2.992768          2.448901           1.021480          1.782409
# 334          0.226509          3.142413           1.405992          2.446256
# 210          0.028569          3.705978           2.077243          2.596935
# 350          4.196135          3.493135           0.963474          2.983678
#
#      ZNF706_51123_Exp  ZP3_7784_Exp  ZPBP2_124626_Exp  Pred_MYC_4609_Dep  \
# 926          6.221490      3.648465               0.0           0.906449
# 630          5.771622      5.135863               0.0           0.969998
# 682          5.649903      3.442280               0.0           0.934247
# 514          6.097400      3.881665               0.0           0.935762
# 365          6.210038      0.137504               0.0           0.943986
# ..                ...           ...               ...                ...
# 208          5.876762      0.669027               0.0           0.939641
# 778          6.520422      4.793376               0.0           0.947173
# 334          6.903400      4.120186               0.0           0.966784
# 210          4.680324      5.312520               0.0           0.975523
# 350          5.877990      4.272023               0.0           0.993591
#
#      MYC_4609_Dep
# 926      0.986031
# 630      0.808635
# 682      0.999965
# 514      0.973706
# 365      0.947456
# ..            ...
# 208      0.981174
# 778      0.851388
# 334      0.999722
# 210      0.971561
# 350      0.999956
#
# [201 rows x 760 columns]

# %%
# MYC_ng_01.csv

# Retrieve the 'DepMap_ID' column before splitting
depmap_id_column = data['DepMap_ID']

# Create a new DataFrame for the test set with the predicted and actual values
test_data = X_test.copy()

# Add 'DepMap_ID' column to test_data
test_data.insert(0, 'DepMap_ID', depmap_id_column.iloc[X_test.index].values)

target_col = "MYC_4609_Dep"  # Replace with the name of your target column

pred_col = f'Pred_{target_col}'
test_data[pred_col] = y_pred[:, 0]  # Assign predicted values to the new column

actual_col = target_col
test_data[actual_col] = y_test.values  # Assign actual values to the target column

# Save the DataFrame to a CSV file
test_data.to_csv("/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_ng_01.csv", index=False)

# Display the updated DataFrame
test_data
# Out:
#       DepMap_ID  A4GNT_51146_Exp  AADAT_51166_Exp  AAGAB_79719_Exp  \
# 926  ACH-001858         0.056584         1.485427         5.270155
# 630  ACH-000962         0.014355         2.859970         4.495056
# 682  ACH-001164         0.000000         1.244887         3.508429
# 514  ACH-000799         0.124328         2.643856         5.154211
# 365  ACH-000571         0.214125         1.176323         4.888987
# ..          ...              ...              ...              ...
# 208  ACH-000339         0.028569         3.117695         4.589164
# 778  ACH-001454         0.000000         2.695994         5.256633
# 334  ACH-000522         0.014355         3.488001         6.149341
# 210  ACH-000343         0.097611         3.173127         5.181898
# 350  ACH-000549         0.000000         0.903038         5.238787
#
#      AAK1_22848_Exp  AAMDC_28971_Exp  AAR2_25980_Exp  ABCA3_21_Exp  \
# 926        2.906891         6.151575        4.571677      0.097611
# 630        2.438293         4.207112        4.361768      4.465322
# 682        2.063503         7.030557        4.408032      4.285402
# 514        3.282440         5.171527        4.694323      3.617063
# 365        3.517276         5.319762        5.401562      0.464668
# ..              ...              ...             ...           ...
# 208        3.252476         5.763943        5.034744      1.678072
# 778        2.944858         6.258142        4.345538      1.831877
# 334        3.329124         4.959770        4.344118      3.007196
# 210        3.632268         6.617504        4.383359      4.875289
# 350        3.600508         4.702103        4.757557      0.555816
#
#      ABCB6_10058_Exp  ABCC9_10060_Exp  ...  ZSWIM4_65249_Exp  \
# 926         4.060047         0.871844  ...          3.647315
# 630         3.661065         0.000000  ...          1.636915
# 682         3.900142         1.298658  ...          3.447579
# 514         5.572283         0.028569  ...          3.053111
# 365         6.077457         0.028569  ...          2.618239
# ..               ...              ...  ...               ...
# 208         4.621173         0.823749  ...          1.604071
# 778         4.793896         0.400538  ...          2.613532
# 334         1.560715         0.084064  ...          2.831877
# 210         2.801159         0.042644  ...          3.430285
# 350         2.432959         0.028569  ...          2.226509
#
#      ZSWIM5_57643_Exp  ZSWIM6_57688_Exp  ZSWIM8_23053_Exp  ZXDB_158586_Exp  \
# 926          0.310340          2.778209          5.402586         2.451541
# 630          0.739848          2.157044          4.672991         2.538538
# 682          0.584963          2.596935          4.546586         1.244887
# 514          1.922198          2.589763          6.254178         1.475085
# 365          0.505891          3.643856          5.728465         1.918386
# ..                ...               ...               ...              ...
# 208          0.555816          2.809414          4.851499         1.769772
# 778          1.195348          2.942984          5.676098         1.847997
# 334          0.163499          2.195348          5.879706         1.879706
# 210          2.891419          2.707083          5.228819         5.212180
# 350          0.275007          2.970854          5.474760         1.974529
#
#      ZYG11B_79699_Exp  ZYX_7791_Exp  ZZZ3_26009_Exp  Pred_MYC_4609_Dep  \
# 926          2.976364      7.199967        4.780310           0.957288
# 630          2.980025      6.212569        3.919340           0.983475
# 682          2.495695      4.735522        3.363171           0.927890
# 514          2.077243      7.966477        3.481557           0.966794
# 365          3.114367      6.934281        4.527946           0.938784
# ..                ...           ...             ...                ...
# 208          2.367371      7.258236        4.584361           0.977347
# 778          2.459432      5.038261        2.657640           0.991445
# 334          3.238787      7.097295        4.649041           0.964659
# 210          3.869871      3.674687        4.669027           0.975617
# 350          2.176323      5.941811        3.982765           0.990567
#
#      MYC_4609_Dep
# 926      0.986031
# 630      0.808635
# 682      0.999965
# 514      0.973706
# 365      0.947456
# ..            ...
# 208      0.981174
# 778      0.851388
# 334      0.999722
# 210      0.971561
# 350      0.999956
#
# [201 rows x 3976 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_paths = [
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_filtered_arranged_table.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_gt_00.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_gt_01.csv',
    '/content/drive/MyDrive/Colab Notebooks/correlation_table_filter_all/KNN_MYC_ng_01.csv'
]

dfs = []  # List to store the DataFrames

# Read each CSV file and append to the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dfs.append(df)

# Create subplots
fig, axs = plt.subplots(1, 4, figsize=(16, 4))
fig.suptitle('KNN Scatter Plots')

# Create scatter plots
titles = ['Without Features Filtering', 'Feature Correlation Values > 0', 'Feature Correlation Values > 0.1',
          'Feature Correlation Values < -0.1']

for i, df in enumerate(dfs):
    ax = axs[i]  # Select the subplot
    ax.scatter(df['Pred_MYC_4609_Dep'], df['MYC_4609_Dep'],c='purple', alpha=0.5)
    ax.set_xlabel('Pred_MYC_4609_Dep')
    ax.set_ylabel('MYC_4609_Dep')
    ax.set_title(titles[i])

# Adjust spacing between subplots
fig.tight_layout()

# Show the plots
plt.show()
