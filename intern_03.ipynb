# %% [markdown]
# <a href="https://colab.research.google.com/github/chingyaousf/Intern-project/blob/main/intern_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Read in the 22Q2 CRISPR_gene_dependency.csv
dependency = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/22Q2 CRISPR_gene_dependency.csv")
dependency

# %%
# Read the CSV file
dependency = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/22Q2 CRISPR_gene_dependency.csv")

# Transpose the DataFrame
dependency_transposed = dependency.transpose()

# Reset the index and set new column names
dependency_transposed = dependency_transposed.reset_index()
dependency_transposed.columns = dependency_transposed.iloc[0]
dependency_transposed = dependency_transposed.iloc[1:]

# Adjust the leftmost column to count from 0
dependency_transposed.reset_index(drop=True, inplace=True)

# Save the transposed DataFrame to a CSV file
dependency_transposed.to_csv("/content/drive/MyDrive/Colab Notebooks/dependency_transposed.csv", index=False)

dependency_transposed

# %%
 # Read the CSV file
gene_expression = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/22Q2 CCLE_expression.csv")

# Transpose the DataFrame
gene_expression_transposed = gene_expression.transpose()

# Reset the index and set new column names
gene_expression_transposed = gene_expression_transposed.reset_index()
gene_expression_transposed.columns = gene_expression_transposed.iloc[0]
gene_expression_transposed = gene_expression_transposed.iloc[1:]

# Adjust the leftmost column to count from 0
gene_expression_transposed.reset_index(drop=True, inplace=True)

# Change the value in the "Unnamed: 0" column to "DepMap_ID"
gene_expression_transposed.rename(columns={"Unnamed: 0": "DepMap_ID"}, inplace=True)

# Save the transposed DataFrame to a CSV file
gene_expression_transposed.to_csv("/content/drive/MyDrive/Colab Notebooks/gene_expression_transposed.csv", index=False)

gene_expression_transposed

# %%
# Read in the 22Q2 CCLE_expression.csv for gene_expression
gene_expression = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/22Q2 CCLE_expression.csv",index_col=0)
gene_expression

# %%
# Find the common column names
common_cols = set(crispr.columns).intersection(set(gene_expression.columns))

# Print the common column names
print(common_cols)
# Out:
# {'MAP4K4 (9448)', 'UBAP2L (9898)', 'BPIFA3 (128861)', 'ARHGEF9 (23229)', 'VHL (7428)', 'UPK2 (7379)', 'CALM1 (801)', 'CNR2 (1269)', 'IKBKB (3551)', 'EIF1AX (1964)', 'SYNJ2 (8871)', 'ECEL1 (9427)', 'ELF5 (2001)', 'ZNF285 (26974)', 'DPCD (25911)', 'SGCB (6443)', 'GAL (51083)', 'CNBP (7555)', 'SLC25A3 (5250)', 'AOC2 (314)', 'ITSN2 (50618)', 'MTIF2 (4528)', 'PSKH1 (5681)', 'MSL1 (339287)', 'HTRA3 (94031)', 'LIG1 (3978)', 'MFSD3 (113655)', 'DEAF1 (10522)', 'TPD52 (7163)', 'ANGPTL2 (23452)', 'ADCYAP1R1 (117)', 'H2AZ2 (94239)', 'TBC1D21 (161514)', 'TMEM42 (131616)', 'AADAT (51166)', 'ANKRD35 (148741)', 'TNRC18 (84629)', 'ARSF (416)', 'TGM3 (7053)', 'TMED4 (222068)', 'NOG (9241)', 'NLRC4 (58484)', 'ATM (472)', 'FAM25A (643161)', 'CAPNS2 (84290)', 'ASB17 (127247)', 'UCHL5 (51377)', 'GAS2L2 (246176)', 'N
098)', 'ALG9 (79796)', 'MPRIP (23164)', 'RBL2 (5934)', 'C8orf34 (116328)', 'MAGOHB (55110)', 'KCNT2 (343450)', 'MYADM (91663)', 'POLR3A (11128)', 'SYMPK (8189)', 'CHMP6 (79643)', 'EVPL (2125)', 'RNASE8 (122665)', 'CEL (1056)', 'VASN (114990)', 'AIMP2 (7965)', 'POU2F2 (5452)', 'BCL3 (602)', 'DPT (1805)', 'ZNF532 (55205)', 'USH1C (10083)', 'CLDN1 (9076)', 'ZNF665 (79788)', 'DEFB126 (81623)', 'EPS8L3 (79574)', 'RESP18 (389075)', 'ZNF205 (7755)', 'ARL13A (392509)', 'TRMT10A (93587)', 'GJA3 (2700)', 'CEBPA (1050)', 'POLK (51426)', 'MKX (283078)', 'DCAF12L2 (340578)', 'KCTD20 (222658)', 'H2AC4 (8335)', 'MRPS33 (51650)', 'XIAP (331)', 'RAB7A (7879)', 'PHOSPHO1 (162466)', 'SDR9C7 (121214)', 'SGCZ (137868)', 'TMCO2 (127391)', 'PIP4P2 (55529)', 'MME (4311)', 'ZSWIM8 (23053)', 'NCOA2 (10499)', 'HLA-DQA1 (3117)', 'LIMD2 (80774)', 'SNX24 (28966)', 'EIF4G3 (8672)', 'HMGA2 (8091)', 'UQCC1 (55245)', 'VSNL1 (7447)', 'ZNF224 (7767)', 'ARHGAP28 (79822)', 'OSBPL1A (114876)', 'APEX2 (27301)', 'PHYHD1 (254295)', 'ZNF567 (163081)', 'RGP1 (9827)', 'CALHM5 (254228)', 'MAPKAPK5 (8550)', 'ST3GAL5 (8869)', 'MPST (4357)', 'ANKRD27 (84079)', 'R3HDM1 (23518)', 'SHC1 (6464)', 'ASMTL (8623)', ...

# %%
num_common_cols = len(common_cols)
print(f"There are {num_common_cols} common column names between the two datasets.")
# Out:
# There are 17283 common column names between the two datasets.

# %%
# Check if the gene name "RGL2 (5863)" is present in both datasets
if "RGL2 (5863)" in common_cols:
    print("The gene name 'RGL2 (5863)' is present in both datasets.")
else:
    print("The gene name 'RGL2 (5863)' is not present in both datasets.")
# Out:
# The gene name 'RGL2 (5863)' is present in both datasets.

# %%
if "RGL2 (5863)" in crispr.columns and "RGL2 (5863)" in gene_expression.columns:
    print("The gene RGL2 (5863) is present in both datasets")
else:
    print("The gene RGL2 (5863) is not present in both datasets")
# Out:
# The gene RGL2 (5863) is present in both datasets

# %%
# Merge the two files based on the cell line ID
merged_data = pd.merge(crispr, gene_expression, left_on="DepMap_ID", right_index=True)
merged_data
# Out:
#       DepMap_ID  A1BG (1)_x  A1CF (29974)_x  A2M (2)_x  A2ML1 (144568)_x  \
# 0    ACH-000001   -0.134808        0.059764  -0.008665         -0.003572
# 1    ACH-000004    0.081853       -0.056401  -0.106738         -0.014499
# 2    ACH-000005   -0.094196       -0.014598   0.100426          0.169103
# 3    ACH-000007   -0.011544       -0.123189   0.080692          0.061046
# 4    ACH-000009   -0.050782       -0.037466   0.068885          0.090375
# ..          ...         ...             ...        ...               ...
# 829  ACH-001542   -0.148352       -0.126168   0.050410          0.073070
# 830  ACH-001543   -0.098201       -0.025790   0.091197          0.195869
# 833  ACH-001543   -0.098201       -0.025790   0.091197          0.195869
# 832  ACH-001547   -0.094018       -0.083833  -0.008078         -0.039111
# 835  ACH-001547   -0.094018       -0.083833  -0.008078         -0.039111
#
#      A3GALT2 (127550)_x  A4GALT (53947)_x  A4GNT (51146)_x  AAAS (8086)_x  \
# 0             -0.106211         -0.008257         0.018711      -0.291985
# 1              0.078209         -0.137562         0.168657      -0.198560
# 2              0.032363         -0.148050         0.168931      -0.244777
# 3             -0.013454         -0.016922        -0.029474      -0.206516
# 4              0.012634         -0.079339        -0.017808      -0.183192
# ..                  ...               ...              ...            ...
# 829           -0.127284         -0.056223         0.014553      -0.220940
# 830           -0.142288         -0.071623        -0.047429      -0.205483
# 833           -0.142288         -0.071623        -0.047429      -0.205483
# 832            0.137467          0.010611        -0.121688      -0.745459
# 835            0.137467          0.010611        -0.121688      -0.745459
#
#      AACS (65985)_x  ...  H3C2 (8358)_y  H3C3 (8352)_y  AC098582.1 (8916)  \
# 0          0.010921  ...       1.137504       0.000000           0.189034
# 1          0.133372  ...       0.536053       0.505891           0.731183
# 2         -0.086871  ...       0.895303       1.350497           0.695994
# 3         -0.063998  ...       1.220330       0.000000           0.163499
# 4          0.006227  ...       0.956057       0.000000           0.321928
# ..              ...  ...            ...            ...                ...
# 829        0.026697  ...       1.042644       0.286881           0.150560
# 830       -0.052062  ...       0.704872       0.565597           0.584963
# 833       -0.052062  ...       0.704872       0.565597           0.584963
# 832       -0.108543  ...       0.378512       0.321928           0.150560
# 835       -0.108543  ...       0.378512       0.321928           0.150560
#
#      DUS4L-BCAP29 (115253422)  C8orf44-SGK3 (100533105)  ELOA3B (728929)  \
# 0                    1.794936                  0.201634         0.000000
# 1                    2.643856                  0.097611         0.000000
# 2                    2.709291                  0.678072         0.000000
# 3                    2.182692                  0.111031         0.000000
# 4                    2.319040                  0.000000         0.000000
# ..                        ...                       ...              ...
# 829                  1.097611                  0.000000         0.000000
# 830                  1.608809                  0.526069         0.014355
# 833                  1.608809                  0.526069         0.014355
# 832                  1.454176                  0.275007         0.000000
# 835                  1.454176                  0.275007         0.000000
#
#      NPBWR1 (2831)_y  ELOA3D (100506888)  ELOA3 (162699)  CDR1 (1038)_y
# 0           0.028569            0.000000        0.214125       0.014355
# 1           0.000000            0.000000        0.000000       0.000000
# 2           0.000000            0.000000        0.000000       0.000000
# 3           0.000000            0.000000        0.000000       0.000000
# 4           0.000000            0.000000        0.000000       0.000000
# ..               ...                 ...             ...            ...
# 829         1.405992            0.000000        0.000000       0.000000
# 830         2.568032            0.014355        0.014355       0.014355
# 833         2.568032            0.014355        0.014355       0.014355
# 832         0.000000            0.000000        0.000000       0.000000
# 835         0.000000            0.000000        0.000000       0.000000
#
# [818 rows x 36608 columns]
