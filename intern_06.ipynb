# %% [markdown]
# <a href="https://colab.research.google.com/github/chingyaousf/Intern-project/blob/main/intern_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#combine 2 split files to correlation_table, file size too big, not enough memory to run it, correlation_table 1.8G 

import pandas as pd

# Read the two CSV files into separate DataFrames
part1_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_part1.csv')
part2_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_part2.csv')

# Concatenate the two DataFrames vertically
correlation_table = pd.concat([part1_df, part2_df])

# Reset the index of the correlation_table DataFrame
correlation_table = correlation_table.reset_index(drop=True)

# Print the correlation_table DataFrame
correlation_table

# %%
# correlation_table_02 1.08G (partial of correlation_table 1.8G)

import pandas as pd

# Read the CSV file into a DataFrame
correlation_table_02 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_02.csv', index_col=0)

# Print the correlation_table_test DataFrame
correlation_table_02
# Out:
#                       A1BG (1) Dep  A1CF (29974) Dep  A2M (2) Dep  \
# DepMap_ID
# A1BG (1) Exp                 0.028            -0.029        0.032
# A1CF (29974) Exp            -0.033             0.004       -0.003
# A2M (2) Exp                 -0.049            -0.098       -0.007
# A2ML1 (144568) Exp          -0.030             0.094        0.059
# A3GALT2 (127550) Exp        -0.022            -0.008        0.022
# ...                            ...               ...          ...
# PDK2 (5164) Exp              0.017            -0.031       -0.043
# PDK3 (5165) Exp             -0.030             0.039        0.015
# PDK4 (5166) Exp             -0.041            -0.004        0.040
# PDLIM1 (9124) Exp            0.006             0.017       -0.029
# PDLIM2 (64236) Exp           0.071            -0.051       -0.000
#
#                       A2ML1 (144568) Dep  A3GALT2 (127550) Dep  \
# DepMap_ID
# A1BG (1) Exp                       0.012                -0.013
# ...

# %%
#Gernerate correlation_table_test for testing the codes following

import pandas as pd

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_02.csv', index_col=0)

# Select the subset of rows and columns
correlation_table_test = correlation_table.iloc[:1000, :1000]

# Save the correlation_table_test DataFrame to a CSV file
correlation_table_test.to_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index=True)

# Print the correlation_table_test DataFrame
correlation_table_test
# Out:
#                         A1BG (1) Dep  A1CF (29974) Dep  A2M (2) Dep  \
# DepMap_ID
# A1BG (1) Exp                   0.028            -0.029        0.032
# A1CF (29974) Exp              -0.033             0.004       -0.003
# A2M (2) Exp                   -0.049            -0.098       -0.007
# A2ML1 (144568) Exp            -0.030             0.094        0.059
# A3GALT2 (127550) Exp          -0.022            -0.008        0.022
# ...                              ...               ...          ...
# ARMC9 (80210) Exp              0.033             0.003       -0.008
# ARMCX1 (51309) Exp            -0.009            -0.088        0.010
# ARMCX2 (9823) Exp             -0.002            -0.095        0.012
# ARMCX3 (51566) Exp            -0.011            -0.040        0.012
# ARMCX4 (100131755) Exp         0.044            -0.046        0.017
#
#                         A2ML1 (144568) Dep  A3GALT2 (127550) Dep  \
# DepMap_ID
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
correlation_table_test= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Print the correlation_table_test DataFrame
correlation_table_test
# Out:
#                         A1BG (1) Dep  A1CF (29974) Dep  A2M (2) Dep  \
# DepMap_ID
# A1BG (1) Exp                   0.028            -0.029        0.032
# A1CF (29974) Exp              -0.033             0.004       -0.003
# A2M (2) Exp                   -0.049            -0.098       -0.007
# A2ML1 (144568) Exp            -0.030             0.094        0.059
# A3GALT2 (127550) Exp          -0.022            -0.008        0.022
# ...                              ...               ...          ...
# ARMC9 (80210) Exp              0.033             0.003       -0.008
# ARMCX1 (51309) Exp            -0.009            -0.088        0.010
# ARMCX2 (9823) Exp             -0.002            -0.095        0.012
# ARMCX3 (51566) Exp            -0.011            -0.040        0.012
# ARMCX4 (100131755) Exp         0.044            -0.046        0.017
#
#                         A2ML1 (144568) Dep  A3GALT2 (127550) Dep  \
# DepMap_ID
# ...

# %%
# Generate very small file (correlation_table_test_small) for checking diagonal values 

import pandas as pd

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Select the subset of rows and columns
correlation_table_test_small = correlation_table.iloc[:5, :5]

# Save the correlation_table_test_small DataFrame to a CSV file
correlation_table_test_small.to_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test_small.csv',index=True)

# Print the correlation_table_test_small DataFrame
correlation_table_test_small
# Out:
#                       A1BG (1) Dep  A1CF (29974) Dep  A2M (2) Dep  \
# DepMap_ID
# A1BG (1) Exp                 0.028            -0.029        0.032
# A1CF (29974) Exp            -0.033             0.004       -0.003
# A2M (2) Exp                 -0.049            -0.098       -0.007
# A2ML1 (144568) Exp          -0.030             0.094        0.059
# A3GALT2 (127550) Exp        -0.022            -0.008        0.022
#
#                       A2ML1 (144568) Dep  A3GALT2 (127550) Dep
# DepMap_ID
# A1BG (1) Exp                       0.012                -0.013
# A1CF (29974) Exp                  -0.051                -0.011
# A2M (2) Exp                       -0.098                -0.017
# A2ML1 (144568) Exp                 0.013                -0.018
# A3GALT2 (127550) Exp              -0.034                 0.025

# %%
import pandas as pd
import numpy as np

# Read the CSV file into a DataFrame
correlation_tabl_samll = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test_small.csv')

correlation_table_test_small
# Out:
#                       A1BG (1) Dep  A1CF (29974) Dep  A2M (2) Dep  \
# DepMap_ID
# A1BG (1) Exp                 0.028            -0.029        0.032
# A1CF (29974) Exp            -0.033             0.004       -0.003
# A2M (2) Exp                 -0.049            -0.098       -0.007
# A2ML1 (144568) Exp          -0.030             0.094        0.059
# A3GALT2 (127550) Exp        -0.022            -0.008        0.022
#
#                       A2ML1 (144568) Dep  A3GALT2 (127550) Dep
# DepMap_ID
# A1BG (1) Exp                       0.012                -0.013
# A1CF (29974) Exp                  -0.051                -0.011
# A2M (2) Exp                       -0.098                -0.017
# A2ML1 (144568) Exp                 0.013                -0.018
# A3GALT2 (127550) Exp              -0.034                 0.025

# %%
#checking diagonal values whether match the values of correlation_table_test_small

import pandas as pd
import numpy as np

# Read the CSV file into a DataFrame
correlation_table= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test_small.csv', index_col=0)

# Get the diagonal values
diagonal_values = np.diag(correlation_table.values)

# Print the diagonal values
print(diagonal_values)
# Out:
# [ 0.028  0.004 -0.007  0.013  0.025]

# %%
#diagonal values violin plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv',index_col=0)

# Get the diagonal area values
diagonal_values = correlation_table.values.diagonal()

# Create a DataFrame for the diagonal values
diagonal_df = pd.DataFrame(diagonal_values,columns=['Correlation distribution'])

# Create a violin plot
sns.violinplot(data=diagonal_df)

# Set plot labels and title

plt.ylabel('Correlation Density')
plt.title('Distribution of Correlation Values')

# Show the plot
plt.show()

# %%
#diagonal values violin, histogram and boxplot plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv',index_col=0)

# Get the diagonal area values
diagonal_values = correlation_table.values.diagonal()

# Create a DataFrame for the diagonal values
diagonal_df = pd.DataFrame(diagonal_values, columns=['Correlation'])

# Create a figure with subplots for violin plot, histogram, and boxplot
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 12))

# Violin plot
sns.violinplot(data=diagonal_df, ax=ax1)

ax1.set_ylabel('Correlation Density')
ax1.set_title('Distribution of Correlation Values (Violin Plot)')

# Histogram
sns.histplot(data=diagonal_df, x='Correlation', ax=ax2)
ax2.set_xlabel('Correlation')
ax2.set_ylabel('Frequency')
ax2.set_title('Distribution of Correlation Values (Histogram)')

# Boxplot
sns.boxplot(data=diagonal_df, ax=ax3)

ax3.set_ylabel('Correlation Density')
ax3.set_title('Distribution of Correlation Values (Boxplot)')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
#non-diagonal values violin plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Flatten the non-diagonal values
non_diagonal_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the non-diagonal values
non_diagonal_df = pd.DataFrame(non_diagonal_values, columns=['Correlation'])

# Create a violin plot for the non-diagonal values
sns.violinplot(data=non_diagonal_df)

# Set plot title and labels
plt.title('Violin Plot of Non-Diagonal Correlation Values')

plt.ylabel('Correlation Density')

# Show the plot
plt.show()

# %%
#non-diagonal values histogram plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.mask(np.triu(np.ones(correlation_table.shape)).astype(bool))

# Reshape the non-diagonal values into a 1D array
non_diagonal_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the non-diagonal values
non_diagonal_df = pd.DataFrame(non_diagonal_values, columns=['Correlation'])

# Create a histogram for the non-diagonal values
sns.histplot(data=non_diagonal_df, x='Correlation')

# Set plot labels and title
plt.xlabel('Correlation')
plt.ylabel('Frequency')
plt.title('Distribution of Non-Diagonal Correlation Values')

# Show the plot
plt.show()

# %%
#non-diagonal values boxplot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Flatten the non-diagonal values
non_diagonal_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the non-diagonal values
non_diagonal_df = pd.DataFrame(non_diagonal_values, columns=['Correlation'])

# Create a boxplot for the non-diagonal values
sns.boxplot(data=non_diagonal_df)

# Set plot title and labels
plt.title('Boxplot of Non-Diagonal Correlation Values')
plt.ylabel('Correlation density')

# Show the plot
plt.show()

# %%
#non-diagonal values histogram plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Reshape the non-diagonal values into a 1D array
non_diagonal_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the non-diagonal values
non_diagonal_df = pd.DataFrame(non_diagonal_values, columns=['Correlation'])

# Create a histogram for the non-diagonal values
sns.histplot(data=non_diagonal_df, x='Correlation')

# Set plot labels and title
plt.xlabel('Correlation')
plt.ylabel('Frequency')
plt.title('Distribution of Non-Diagonal Correlation Values')

# Show the plot
plt.show()

# %%
#diagonal and non-diagonal values histogram plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Flatten the correlation values
correlation_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the diagonal values
diagonal_values = np.diag(correlation_table)
diagonal_df = pd.DataFrame(diagonal_values, columns=['Diagonal'])

# Create a DataFrame for the non-diagonal values
non_diagonal_df = pd.DataFrame(correlation_values, columns=['Non-Diagonal'])

# Combine the diagonal and non-diagonal DataFrames
combined_df = pd.concat([diagonal_df, non_diagonal_df], axis=1)

# Create the histogram plot
sns.histplot(data=combined_df)

# Set plot labels and title
plt.xlabel('Correlation')
plt.ylabel('Frequency')
plt.title('Distribution of Diagonal and Non-Diagonal Correlation Values')

# Show the plot
plt.show()

# %%
#diagonal and non-diagonal values violin plot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Flatten the correlation values
correlation_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the diagonal values
diagonal_values = np.diag(correlation_table)
diagonal_df = pd.DataFrame(diagonal_values, columns=['Diagonal'])

# Create a DataFrame for the non-diagonal values
non_diagonal_df = pd.DataFrame(correlation_values, columns=['Non-Diagonal'])

# Combine the diagonal and non-diagonal DataFrames
combined_df = pd.concat([diagonal_df, non_diagonal_df], axis=1)

# Create the violin plot
sns.violinplot(data=combined_df)

# Set plot labels and title
plt.xlabel('Value Type')
plt.ylabel('Correlation density')
plt.title('Distribution of Diagonal and Non-Diagonal Correlation Values')

# Show the plot
plt.show()

# %%
#diagonal and non-diagonal values boxplot

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Flatten the correlation values
correlation_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the diagonal values
diagonal_values = np.diag(correlation_table)
diagonal_df = pd.DataFrame(diagonal_values, columns=['Diagonal'])

# Create a DataFrame for the non-diagonal values
non_diagonal_df = pd.DataFrame(correlation_values, columns=['Non-Diagonal'])

# Combine the diagonal and non-diagonal DataFrames
combined_df = pd.concat([diagonal_df, non_diagonal_df], axis=1)

# Create the boxplot
sns.boxplot(data=combined_df)

# Set plot labels and title
plt.xlabel('Value Type')
plt.ylabel('Correlation density')
plt.title('Distribution of Diagonal and Non-Diagonal Correlation Values')

# Show the plot
plt.show()

# %%
#diagonal and non-diagonal values violin, boxplot and histogram plot all together

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Flatten the correlation values
correlation_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the diagonal values
diagonal_values = np.diag(correlation_table)
diagonal_df = pd.DataFrame(diagonal_values, columns=['Diagonal'])

# Create a DataFrame for the non-diagonal values
non_diagonal_values = correlation_values[~np.isnan(correlation_values)]
non_diagonal_df = pd.DataFrame(non_diagonal_values, columns=['Non-Diagonal'])

# Combine the diagonal and non-diagonal DataFrames
combined_df = pd.concat([diagonal_df, non_diagonal_df], axis=1)

# Create subplots with 1 row and 3 columns
fig, axes = plt.subplots(1, 3, figsize=(15, 7))

# Violin plot
sns.violinplot(data=combined_df, ax=axes[0])
axes[0].set_title('Violin Plot')


# Boxplot
sns.boxplot(data=combined_df, ax=axes[1])
axes[1].set_title('Boxplot')


# Histogram
sns.histplot(data=combined_df, ax=axes[2])
axes[2].set_title('Histogram')

# Adjust spacing between subplots
plt.tight_layout()

# Save the plots as images
plt.savefig('/content/drive/MyDrive/Colab Notebooks/intern plots/violin_boxplot_histogram.png')

# Show the plot
plt.show()

# %%
##diagonal and non-diagonal values violin, boxplot and histogram plot individually

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the CSV file into a DataFrame
correlation_table = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/correlation_table_test.csv', index_col=0)

# Exclude the diagonal values
non_diagonal_table = correlation_table.where(np.triu(np.ones(correlation_table.shape), k=1).astype(bool))

# Flatten the correlation values
correlation_values = non_diagonal_table.values.flatten()

# Create a DataFrame for the diagonal values
diagonal_values = np.diag(correlation_table)
diagonal_df = pd.DataFrame(diagonal_values, columns=['Diagonal'])

# Create a DataFrame for the non-diagonal values
non_diagonal_values = correlation_values[~np.isnan(correlation_values)]
non_diagonal_df = pd.DataFrame(non_diagonal_values, columns=['Non-Diagonal'])

# Combine the diagonal and non-diagonal DataFrames
combined_df = pd.concat([diagonal_df, non_diagonal_df], axis=1)

# Violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(data=combined_df)
plt.title('Violin Plot')
plt.ylabel('Correlation Density')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/intern plots/violin_plot.png')
plt.show()
plt.close()

# Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=combined_df)
plt.title('Boxplot')
plt.ylabel('Correlation Density')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/intern plots/boxplot.png')
plt.show()
plt.close()

# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=combined_df)
plt.title('Histogram')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/intern plots/histogram.png')
plt.show()
plt.close()
